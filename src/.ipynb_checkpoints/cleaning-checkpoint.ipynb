# %%
import pandas as pd

# %%
shark = pd.read_csv("/Users/juniorlinhares/Documents/projects/project-I/data/attacks.csv", encoding="Latin-1")
shark.sample()
# Out:
#      Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 9478         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#       ... Species  Investigator or Source  pdf href formula href  \
# 9478  ...      NaN                    NaN  NaN          NaN  NaN
#
#      Case Number.1 Case Number.2 original order Unnamed: 22 Unnamed: 23
# 9478           NaN           NaN            NaN         NaN         NaN
#
# [1 rows x 24 columns]

# %%
shark.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
missing_values = shark.isnull().sum()
missing_values
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
# removing rows with no information in any columns

shark2 = shark.dropna(how='all')
shark2.reset_index(drop=True, inplace=True)
shark2
# Out:
#      Case Number         Date    Year        Type    Country             Area  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# ...          ...          ...     ...         ...        ...              ...
# 8698           0          NaN     NaN         NaN        NaN              NaN
# 8699           0          NaN     NaN         NaN        NaN              NaN
# 8700           0          NaN     NaN         NaN        NaN              NaN
# 8701           0          NaN     NaN         NaN        NaN              NaN
# 8702          xx          NaN     NaN         NaN        NaN              NaN
#
# ...

# %%
# Columns that doesn’t contain useful information

shark3 = shark2.drop(['Case Number', 'pdf', 'href formula', 'href', 'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22', 'Unnamed: 23'], axis=1)
shark3.sample()
# Out:
#              Date    Year        Type       Country           Area Location  \
# 3943  24-Dec-1960  1960.0  Unprovoked  SOUTH AFRICA  KwaZulu-Natal  Margate
#
#       Activity                     Name Sex  Age                Injury  \
# 3943  Swimming  Serame "Petrus" Sithole    M  25  FATAL, legs severed
#
#      Fatal (Y/N)   Time                                           Species   \
# 3943           Y  16h30  White shark, 3 m [10'], tooth fragment from wo...
#
#                                  Investigator or Source
# 3943  D. Davies & J. D'Aubrey; D. Davies, pp. 108-10...

# %%
# Standardizing column names

shark3.columns = [i.lower().replace(" ", "_") for i in shark3.columns]
shark3.sample()
# Out:
#      date  year type country area location activity name sex_  age injury  \
# 8536  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN  NaN    NaN
#
#      fatal_(y/n) time species_ investigator_or_source
# 8536         NaN  NaN      NaN                    NaN

# %%
# Converting date columns

shark3['date'] = pd.to_datetime(shark3['date'], errors='coerce')
shark3.sample()
# Out:
#          date    year        type country     area           location  \
# 81 2017-09-20  2017.0  Unprovoked     USA  Florida  Palm Beach County
#
#    activity            name sex_  age                                  injury  \
# 81  Surfing  Richard Inniss    M  NaN  Minor lacerations to sole of left foot
#
#    fatal_(y/n)     time species_ investigator_or_source
# 81           N  Morning      NaN        WPTV, 9/25/2017

# %%
# Working on 'age' column, excluding letters and wrong text in the rows, using regex101!

shark3['age'] = shark3['age'].astype(str)
shark3['age'] = shark3['age'].str.extract('(\d+)')
shark3['age'] = pd.to_numeric(shark3['age'], errors='coerce')
shark3.sample()
# Out:
#            date    year        type       country           area  \
# 3449 1968-12-02  1968.0  Unprovoked  SOUTH AFRICA  KwaZulu-Natal
#
#            location      activity               name sex_   age  \
# 3449  Bluff, Durban  Spearfishing  Chris Van Niekerk    M  28.0
#
#                                               injury fatal_(y/n) time  \
# 3449  No injury, left elbow & torso bumped by sharks           N  NaN
#
#                                                species_ investigator_or_source
# 3449  2 scalloped hammerhead sharks, 1.5 m & 1.8 m [...        A. Heydorn, ORI

# %%
# Calculating the mean or median age from the available data and fill missing values with that value

mean_age = shark3['age'].mean()
shark3['age'].fillna(mean_age, inplace=False)
shark3
# Out:
#            date    year        type    country             area  \
# 0    2018-06-25  2018.0     Boating        USA       California
# 1    2018-06-18  2018.0  Unprovoked        USA          Georgia
# 2    2018-06-09  2018.0     Invalid        USA           Hawaii
# 3    2018-06-08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4    2018-06-04  2018.0    Provoked     MEXICO           Colima
# ...         ...     ...         ...        ...              ...
# 8698        NaT     NaN         NaN        NaN              NaN
# 8699        NaT     NaN         NaN        NaN              NaN
# 8700        NaT     NaN         NaN        NaN              NaN
# 8701        NaT     NaN         NaN        NaN              NaN
# 8702        NaT     NaN         NaN        NaN              NaN
#
#                             location     activity             name sex_   age  \
# 0        Oceanside, San Diego County     Paddling      Julie Wolfe    F  57.0
# ...
